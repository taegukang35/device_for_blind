# %% [markdown]
# <a href="https://colab.research.google.com/github/taegukang35/rne_pj/blob/main/hallway_unet_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d taegukang0305/semantic-hallway-dataset
# Out:
# semantic-hallway-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/semantic-hallway-dataset.zip
# Out:
# Archive:  /content/semantic-hallway-dataset.zip
# replace school_hallway/annotation_train/1000.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
BATCH_SIZE = 10 # the higher the better
IMG_WIDTH = 256 # for faster computing on kaggle
IMG_HEIGHT = 256 # for faster computing on kaggle
IMG_CHANNELS = 3
seed = 42

# %%
import cv2
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

#https://www.kaggle.com/taegukang0305/unet-imagedatagenerator-lb-0-336/edit

# %%
SIZE_X = 256 #Resize images (height  = X, width = Y)
SIZE_Y = 256
 
#Capture training image info as a list
train_img = []
 
for directory_path in glob.glob("/content/school_hallway/images_train"):
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        #print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_img.append(img)
        #train_labels.append(label)
#Convert list to array for machine learning processing        
train_images = np.array(train_img)
 
#Capture mask/label info as a list
train_mask = [] 
for directory_path in glob.glob("/content/school_hallway/annotation_train"):
    for mask_path in glob.glob(os.path.join(directory_path, "*.png")):
        mask = cv2.imread(mask_path)       
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
        mask = cv2.cvtColor(mask, cv2.COLOR_RGB2BGR)
        train_mask.append(mask)
        #train_labels.append(label)
#Convert list to array for machine learning processing          
train_masks = np.array(train_mask)

# %%
X = train_images
Y = train_mask
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)
 
x_train = np.asarray(x_train).astype('float32')
x_val = np.asarray(x_val).astype('float32')
y_train = np.asarray(y_train)[:,:,:,0].astype('float32')
y_train =  np.expand_dims(y_train,axis=3)
y_val = np.asarray(y_val)[:,:,:,0].astype('float32')
y_val = np.expand_dims(y_val,axis=3)

# %%
x_train.shape
# Out:
# (392, 256, 256, 3)

# %%
from keras.preprocessing import image

# Creating the training Image and Mask generator
image_datagen = image.ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
mask_datagen = image.ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')

# Keep the same seed for image and mask generators so they fit together

image_datagen.fit(x_train[:int(x_train.shape[0]*0.9)], augment=True, seed=seed)
mask_datagen.fit(y_train[:int(y_train.shape[0]*0.9)], augment=True, seed=seed)

x=image_datagen.flow(x_train[:int(x_train.shape[0]*0.9)],batch_size=BATCH_SIZE,shuffle=True, seed=seed)
y=mask_datagen.flow(y_train[:int(y_train.shape[0]*0.9)],batch_size=BATCH_SIZE,shuffle=True, seed=seed)

# Creating the validation Image and Mask generator
image_datagen_val = image.ImageDataGenerator()
mask_datagen_val = image.ImageDataGenerator()

image_datagen_val.fit(x_train[int(x_train.shape[0]*0.9):], augment=True, seed=seed)
mask_datagen_val.fit(y_train[int(y_train.shape[0]*0.9):], augment=True, seed=seed)

x_val=image_datagen_val.flow(x_train[int(x_train.shape[0]*0.9):],batch_size=BATCH_SIZE,shuffle=True, seed=seed)
y_val=mask_datagen_val.flow(y_train[int(y_train.shape[0]*0.9):],batch_size=BATCH_SIZE,shuffle=True, seed=seed)

# %%
# Checking if the images fit

from matplotlib import pyplot as plt
# %matplotlib inline

plt.imshow(x.next()[0].astype(np.uint8))
plt.show()
plt.imshow(np.squeeze(y.next()[0].astype(np.uint8)))
plt.show()
plt.imshow(x_val.next()[0].astype(np.uint8))
plt.show()
plt.imshow(np.squeeze(y_val.next()[0].astype(np.uint8)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-05bc1e7b9122> in <module>()
#       4 get_ipython().magic('matplotlib inline')
#       5
# ----> 6 plt.imshow(x.next()[0].astype(np.uint8))
#       7 plt.show()
#       8 plt.imshow(np.squeeze(y.next()[0].astype(np.uint8)))
#
# NameError: name 'x' is not defined

# %%
#creating a training and validation generator that generate masks and images
train_generator = zip(x, y)
val_generator = zip(x_val, y_val)

# %%
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %%
# Define IoU metric
"""def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred = tf.cast(y_pred > t, dtype=tf.int32)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)"""
def mean_IoU(y_true, y_pred):
	s = K.shape(y_true)

	# reshape such that w and h dim are multiplied together
	y_true_reshaped = K.reshape( y_true, tf.stack( [-1, s[1]*s[2], s[-1]] ) )
	y_pred_reshaped = K.reshape( y_pred, tf.stack( [-1, s[1]*s[2], s[-1]] ) )

	# correctly classified
	clf_pred = K.one_hot( K.argmax(y_pred_reshaped), nb_classes = s[-1])
	equal_entries = K.cast(K.equal(clf_pred,y_true_reshaped), dtype='float32') * y_true_reshaped

	intersection = K.sum(equal_entries, axis=1)
	union_per_class = K.sum(y_true_reshaped,axis=1) + K.sum(y_pred_reshaped,axis=1)

	iou = intersection / (union_per_class - intersection)
	iou_mask = tf.is_finite(iou)
	iou_masked = tf.boolean_mask(iou,iou_mask)

	return K.mean( iou_masked )

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256, 256, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 256, 256, 16) 448         lambda_7[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 256, 256, 16) 0           conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 16) 2320        dropout_63[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 128, 128, 16) 0           conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 128, 128, 32) 4640        max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 128, 128, 32) 0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 128, 128, 32) 9248        dropout_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 64, 64, 64)   18496       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 64, 64, 64)   0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 64, 64, 64)   36928       dropout_65[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 32, 32, 128)  73856       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_66 (Dropout)            (None, 32, 32, 128)  0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 32, 32, 128)  147584      dropout_66[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 16, 16, 256)  295168      max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# dropout_67 (Dropout)            (None, 16, 16, 256)  0           conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 16, 16, 256)  590080      dropout_67[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 32, 32, 128)  131200      conv2d_142[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 32, 32, 256)  0           conv2d_transpose_28[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 32, 32, 128)  295040      concatenate_28[0][0]
# __________________________________________________________________________________________________
# dropout_68 (Dropout)            (None, 32, 32, 128)  0           conv2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 32, 32, 128)  147584      dropout_68[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 64, 64, 64)   32832       conv2d_144[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 64, 64, 128)  0           conv2d_transpose_29[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 64, 64, 64)   73792       concatenate_29[0][0]
# __________________________________________________________________________________________________
# dropout_69 (Dropout)            (None, 64, 64, 64)   0           conv2d_145[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 64, 64, 64)   36928       dropout_69[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 128, 128, 32) 8224        conv2d_146[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 128, 128, 64) 0           conv2d_transpose_30[0][0]
#                                                                  conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 128, 128, 32) 18464       concatenate_30[0][0]
# __________________________________________________________________________________________________
# dropout_70 (Dropout)            (None, 128, 128, 32) 0           conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 128, 128, 32) 9248        dropout_70[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 256, 256, 16) 2064        conv2d_148[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 256, 256, 32) 0           conv2d_transpose_31[0][0]
#                                                                  conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 256, 256, 16) 4624        concatenate_31[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 256, 256, 16) 0           conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 256, 256, 16) 2320        dropout_71[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 256, 256, 1)  17          conv2d_150[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=3, verbose=1)
checkpointer = ModelCheckpoint('model-prgmti1-unet.h5', verbose=1, save_best_only=True)
history = model.fit(x_train,y_train, validation_data=(x_val,y_val), validation_steps=10, steps_per_epoch=10,
                              epochs=1000, callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 9s 898ms/step - loss: 0.6981 - acc: 0.5867 - val_loss: 0.6460 - val_acc: 0.6123
#
# Epoch 00001: val_loss improved from inf to 0.64602, saving model to model-prgmti1-unet.h5
# Epoch 2/1000
# 10/10 [==============================] - 9s 897ms/step - loss: 0.6129 - acc: 0.6433 - val_loss: 0.8065 - val_acc: 0.6071
#
# Epoch 00002: val_loss did not improve from 0.64602
# Epoch 3/1000
# 10/10 [==============================] - 9s 898ms/step - loss: 0.5423 - acc: 0.7114 - val_loss: 0.4806 - val_acc: 0.7654
#
# Epoch 00003: val_loss improved from 0.64602 to 0.48063, saving model to model-prgmti1-unet.h5
# Epoch 4/1000
# 10/10 [==============================] - 9s 901ms/step - loss: 0.5232 - acc: 0.7130 - val_loss: 0.4601 - val_acc: 0.7446
#
# Epoch 00004: val_loss improved from 0.48063 to 0.46012, saving model to model-prgmti1-unet.h5
# Epoch 5/1000
# 10/10 [==============================] - 9s 906ms/step - loss: 0.5457 - acc: 0.6888 - val_loss: 0.4689 - val_acc: 0.7857
#
# Epoch 00005: val_loss did not improve from 0.46012
# Epoch 6/1000
# 10/10 [==============================] - 9s 911ms/step - loss: 0.4754 - acc: 0.7608 - val_loss: 0.4415 - val_acc: 0.7868
#
# Epoch 00006: val_loss improved from 0.46012 to 0.44149, saving model to model-prgmti1-unet.h5
# Epoch 7/1000
# 10/10 [==============================] - 9s 910ms/step - loss: 0.4918 - acc: 0.7507 - val_loss: 0.4455 - val_acc: 0.8146
#
# Epoch 00007: val_loss did not improve from 0.44149
# Epoch 8/1000
# 10/10 [==============================] - 9s 910ms/step - loss: 0.4157 - acc: 0.8203 - val_loss: 0.3643 - val_acc: 0.8469
#
# Epoch 00008: val_loss improved from 0.44149 to 0.36429, saving model to model-prgmti1-unet.h5
# Epoch 9/1000
# 10/10 [==============================] - 9s 914ms/step - loss: 0.4370 - acc: 0.8176 - val_loss: 0.3934 - val_acc: 0.8267
#
# Epoch 00009: val_loss did not improve from 0.36429
# Epoch 10/1000
# 10/10 [==============================] - 9s 910ms/step - loss: 0.3623 - acc: 0.8454 - val_loss: 0.4701 - val_acc: 0.7793
#
# Epoch 00010: val_loss did not improve from 0.36429
# Epoch 11/1000
# 10/10 [==============================] - 9s 909ms/step - loss: 0.3707 - acc: 0.8401 - val_loss: 0.3393 - val_acc: 0.8544
#
# Epoch 00011: val_loss improved from 0.36429 to 0.33931, saving model to model-prgmti1-unet.h5
# Epoch 12/1000
# 10/10 [==============================] - 9s 908ms/step - loss: 0.3339 - acc: 0.8643 - val_loss: 0.3021 - val_acc: 0.8758
#
# Epoch 00012: val_loss improved from 0.33931 to 0.30206, saving model to model-prgmti1-unet.h5
# Epoch 13/1000
# 10/10 [==============================] - 9s 908ms/step - loss: 0.2941 - acc: 0.8805 - val_loss: 0.2949 - val_acc: 0.8828
#
# Epoch 00013: val_loss improved from 0.30206 to 0.29493, saving model to model-prgmti1-unet.h5
# Epoch 14/1000
# 10/10 [==============================] - 9s 907ms/step - loss: 0.2588 - acc: 0.8957 - val_loss: 0.3126 - val_acc: 0.8752
#
# Epoch 00014: val_loss did not improve from 0.29493
# Epoch 15/1000
# 10/10 [==============================] - 9s 905ms/step - loss: 0.2165 - acc: 0.9136 - val_loss: 0.2687 - val_acc: 0.8999
#
# Epoch 00015: val_loss improved from 0.29493 to 0.26872, saving model to model-prgmti1-unet.h5
# Epoch 16/1000
# 10/10 [==============================] - 9s 905ms/step - loss: 0.1963 - acc: 0.9225 - val_loss: 0.3716 - val_acc: 0.8668
#
# Epoch 00016: val_loss did not improve from 0.26872
# Epoch 17/1000
# 10/10 [==============================] - 9s 906ms/step - loss: 0.1642 - acc: 0.9369 - val_loss: 0.3839 - val_acc: 0.8678
#
# Epoch 00017: val_loss did not improve from 0.26872
# Epoch 18/1000
# 10/10 [==============================] - 9s 908ms/step - loss: 0.1395 - acc: 0.9479 - val_loss: 0.2736 - val_acc: 0.9001
#
# Epoch 00018: val_loss did not improve from 0.26872
# Epoch 00018: early stopping

# %%
img_path ='/content/school_hallway/images_test/1345.png'
img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
img = cv2.resize(img, (SIZE_Y, SIZE_X))
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %%
img = np.asarray(img).astype('float32')
img = np.expand_dims(img,axis=0)
mask = model.predict(img)

# %%
plt.imshow(mask[0][:,:,0])

# %%
def make_mask(img_path):
  img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
  img = cv2.resize(img, (SIZE_Y, SIZE_X))
  img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
  plt.imshow(img)
  plt.show()
  img = np.asarray(img).astype('float32')
  img = np.expand_dims(img,axis=0)
  mask = model.predict(img)
  plt.imshow(mask[0][:,:,0])
  plt.show()

# %%
make_mask('/content/school_hallway/images_test/1341.png')

# %%
make_mask('/content/school_hallway/images_train/1012.png')

# %%
make_mask('/content/school_hallway/images_test/9.png')

# %%
make_mask('/content/school_hallway/images_test/26.png')

# %%
make_mask('/content/school_hallway/images_test/95.png')

# %%
make_mask('/content/school_hallway/images_test/0.png')

# %%
make_mask('/content/school_hallway/images_test/25.png')

# %%
make_mask('/content/drive/MyDrive/myfile/20210705_232541.jpg')

# %%
make_mask('/content/drive/MyDrive/myfile/20210705_232535.jpg')

# %%
make_mask('/content/drive/MyDrive/myfile/20210705_232504.jpg')
